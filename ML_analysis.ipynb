# %% [markdown]
# # Analysis of 3 ML Predictions

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data_2020.csv')
data_pred_2020 = pd.read_csv('climate_pred_2020.csv')
data_pred_2019 = pd.read_csv('climate_pred_2019.csv')
data_pred_2018 = pd.read_csv('climate_pred_2018.csv')
all_data_pred_2020 = pd.read_csv('climate_all_pred_2020.csv')
all_data_pred_2019 = pd.read_csv('climate_all_pred_2019.csv')
all_data_pred_2018 = pd.read_csv('climate_all_pred_2018.csv')

# %%
data.drop(columns=['Unnamed: 0'],inplace=True)
data_pred_2020.drop(columns=['Unnamed: 0'],inplace=True)
data_pred_2019.drop(columns=['Unnamed: 0'],inplace=True)
data_pred_2018.drop(columns=['Unnamed: 0'],inplace=True)
all_data_pred_2020.drop(columns=['Unnamed: 0','level_0'],inplace=True)
all_data_pred_2019.drop(columns=['Unnamed: 0'],inplace=True)
all_data_pred_2018.drop(columns=['Unnamed: 0'],inplace=True)

# %%
all_data_pred_2018.head()
# Out:
#    country  year    CDA       CHA  FGA        NDA    BCA
# 0  Albania  1995  100.0  73.07252  0.0  78.221486  100.0
# 1  Albania  1996  100.0  73.07252  0.0  78.221486  100.0
# 2  Albania  1997  100.0  73.07252  0.0  78.221486  100.0
# 3  Albania  1998  100.0  73.07252  0.0  78.221486  100.0
# 4  Albania  1999  100.0  73.07252  0.0  78.221486  100.0

# %%
f, ax = plt.subplots(figsize=(11,7))
sns.lineplot(x="year", y="CDA", data=data, color='purple',ci=0.5)
sns.lineplot(x="year", y="CDA", data=data_pred_2020, color='green',dashes=True,ci=0.5,label='2020')
sns.lineplot(x="year", y="CDA", data=data_pred_2019, color='magenta',dashes=True,ci=0.5,label='2019')
sns.lineplot(x="year", y="CDA", data=data_pred_2018, color='brown',dashes=True,ci=0.5,label='2018')
plt.show()

# %%
f.savefig('./templates/images/cda.png')

# %%
f, ax = plt.subplots(figsize=(11,7))
sns.lineplot(x="year", y="CHA", data=data, color='purple',ci=0.5)
sns.lineplot(x="year", y="CHA", data=data_pred_2020, color='green',dashes=True,ci=0.5,label='2020')
sns.lineplot(x="year", y="CHA", data=data_pred_2019, color='magenta',dashes=True,ci=0.5,label='2019')
sns.lineplot(x="year", y="CHA", data=data_pred_2018, color='brown',dashes=True,ci=0.5,label='2018')
plt.show()

# %%
f.savefig('./templates/images/cha.png')

# %%
f, ax = plt.subplots(figsize=(11,7))
sns.lineplot(x="year", y="FGA", data=data, color='purple',ci=0.5)
sns.lineplot(x="year", y="FGA", data=data_pred_2020, color='green',dashes=True,ci=0.5,label='2020')
sns.lineplot(x="year", y="FGA", data=data_pred_2019, color='magenta',dashes=True,ci=0.5,label='2019')
sns.lineplot(x="year", y="FGA", data=data_pred_2018, color='brown',dashes=True,ci=0.5,label='2018')
plt.show()

# %%
f.savefig('./templates/images/fga.png')

# %%
f, ax = plt.subplots(figsize=(11,7))
sns.lineplot(x="year", y="NDA", data=data, color='purple',ci=0.5)
sns.lineplot(x="year", y="NDA", data=data_pred_2020, color='green',dashes=True,ci=0.5,label='2020')
sns.lineplot(x="year", y="NDA", data=data_pred_2019, color='magenta',dashes=True,ci=0.5,label='2019')
sns.lineplot(x="year", y="NDA", data=data_pred_2018, color='brown',dashes=True,ci=0.5,label='2018')
plt.show()

# %%
f.savefig('./templates/images/nda.png')

# %%
f, ax = plt.subplots(figsize=(11,7))
sns.lineplot(x="year", y="BCA", data=data, color='purple',ci=0.5)
sns.lineplot(x="year", y="BCA", data=data_pred_2020, color='green',dashes=True,ci=0.5,label='2020')
sns.lineplot(x="year", y="BCA", data=data_pred_2019, color='magenta',dashes=True,ci=0.5,label='2019')
sns.lineplot(x="year", y="BCA", data=data_pred_2018, color='brown',dashes=True,ci=0.5,label='2018')
plt.show()

# %%
f.savefig('./templates/images/bca.png')
